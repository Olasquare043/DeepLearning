# %% [markdown]
# <a href="https://colab.research.google.com/github/Olasquare043/DeepLearning/blob/main/torchclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
if torch.cuda.is_available():
  print ("cuda")
else:
   print("cpu")
# Out:
# cpu
